# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cycles_df = pd.read_csv('Cleaned-Data/cleaned-physiological-cycles.csv')
cycles_df.head()
# Out:
#       Cycle start time       Cycle end time Cycle timezone  Recovery score %  \
# 0  2021-10-16 22:13:29  2021-10-17 23:26:57      UTC-04:00              58.0
# 1  2021-10-15 23:10:05  2021-10-16 22:13:29      UTC-04:00              25.0
# 2  2021-10-14 23:51:49  2021-10-15 23:10:05      UTC-04:00              45.0
# 3  2021-10-13 23:00:18  2021-10-14 23:51:49      UTC-04:00              18.0
# 4  2021-10-13 00:56:19  2021-10-13 23:00:18      UTC-04:00              44.0
#
#    Resting heart rate (bpm)  Heart rate variability (ms)  Day Strain  \
# 0                      37.0                         69.0        16.3
# 1                      36.0                         46.0        19.8
# 2                      38.0                         66.0        17.9
# 3                      37.0                         45.0        19.5
# 4                      37.0                         73.0        18.3
#
#    Energy burned (cal)  Max HR (bpm)  Average HR (bpm)  ...  \
# ...

# %%
cycles_df.describe()
# Out:
#        Recovery score %  Resting heart rate (bpm)  \
# count        102.000000                102.000000
# mean          54.627451                 36.186275
# std           17.434983                  0.941143
# min           18.000000                 34.000000
# 25%           42.000000                 36.000000
# 50%           54.500000                 36.000000
# 75%           67.000000                 37.000000
# max           93.000000                 39.000000
#
#        Heart rate variability (ms)  Day Strain  Energy burned (cal)  \
# count                   102.000000  102.000000           102.000000
# mean                     78.735294   18.620588          3582.833333
# std                      14.556769    1.603235           543.978725
# min                      45.000000   12.000000          2091.000000
# 25%                      70.250000   17.700000          3292.250000
# 50%                      79.000000   18.850000          3554.000000
# ...

# %%
cycles_df.shape
# Out:
# (102, 25)

# %%
cycles_df.isnull().sum()
# Out:
# Cycle start time               0
# Cycle end time                 0
# Cycle timezone                 0
# Recovery score %               0
# Resting heart rate (bpm)       0
# Heart rate variability (ms)    0
# Day Strain                     0
# Energy burned (cal)            0
# Max HR (bpm)                   0
# Average HR (bpm)               0
# Sleep performance %            0
# Respiratory rate (rpm)         0
# Asleep duration (min)          0
# In bed duration (min)          0
# Light sleep duration (min)     0
# Deep (SWS) duration (min)      0
# REM duration (min)             0
# Awake duration (min)           0
# Sleep need (min)               0
# Sleep debt (min)               0
# Sleep efficiency %             0
# Sleep consistency %            0
# Recovery category              0
# day_of_week                    0
# Day of the week                0
# dtype: int64

# %% [markdown]
# Making sure everything from the preprocessing is good.

# %%
# Plotting the distribution of Recovery Scores
plt.figure(figsize=(8, 6))
plt.hist(cycles_df['Recovery score %'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Recovery Scores')
plt.xlabel('Recovery Scores')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The Effect Strain has on Sleep

# %%
plt.figure(figsize=(12, 6))  

plt.subplot(1, 2, 1)
plt.scatter(cycles_df['Day Strain'], cycles_df['Asleep duration (min)'], c='skyblue', marker='o', label='Data Points', edgecolor='black')
plt.xlabel('Strain')
plt.ylabel('Sleep Time')
plt.title('Scatter Plot of Strain vs. Sleep Time')

plt.subplot(1, 2, 2)
plt.scatter(cycles_df['Day Strain'], cycles_df['Sleep efficiency %'], c='skyblue', marker='o', label='Data Points', edgecolor='black')
plt.xlabel('Strain')
plt.ylabel('Sleep Efficiency')
plt.title('Scatter Plot of Strain vs. Sleep Efficiency')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Strain vs. Sleep Efficiency')

# %%
plt.figure(figsize=(18, 6))  

plt.subplot(1, 3, 1)
plt.scatter(cycles_df['Day Strain'], cycles_df['Light sleep duration (min)'], c='skyblue', marker='o', label='Data Points', edgecolor='black')
plt.xlabel('Strain')
plt.ylabel('Light Sleep (Min)')
plt.title('Scatter Plot of Strain vs. Light Sleep')

plt.subplot(1, 3, 2)
plt.scatter(cycles_df['Day Strain'], cycles_df['Deep (SWS) duration (min)'], c='skyblue', marker='o', label='Data Points', edgecolor='black')
plt.xlabel('Strain')
plt.ylabel('Deep Sleep')
plt.title('Scatter Plot of Strain vs. Deep Sleep')

plt.subplot(1, 3, 3)
plt.scatter(cycles_df['Day Strain'], cycles_df['REM duration (min)'], c='skyblue', marker='o', label='Data Points', edgecolor='black')
plt.xlabel('Strain')
plt.ylabel('REM Sleep (Min)')
plt.title('Scatter Plot of Strain vs. REM Sleep')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Strain vs. REM Sleep')

# %%
correlation_matrix = cycles_df[['Day Strain', 'Asleep duration (min)', 'Sleep efficiency %','Light sleep duration (min)', 'Deep (SWS) duration (min)', 'REM duration (min)']].corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The effect calories burned has on sleep

# %%
# calories burned vs sleep time, calories burned vs sleep efficiency 
plt.figure(figsize=(12, 6))  

plt.subplot(1, 2, 1)
plt.scatter(cycles_df['Energy burned (cal)'], cycles_df['Asleep duration (min)'], c='skyblue', marker='o', label='Data Points', edgecolor='black')
plt.xlabel('Calories Burned')
plt.ylabel('Sleep Time')
plt.title('Scatter Plot of Calories Burned vs. Sleep Time')

plt.subplot(1, 2, 2)
plt.scatter(cycles_df['Energy burned (cal)'], cycles_df['Sleep efficiency %'], c='skyblue', marker='o', label='Data Points', edgecolor='black')
plt.xlabel('Calories Burned')
plt.ylabel('Sleep Efficiency')
plt.title('Scatter Plot of Calories Burned vs. Sleep Efficiency')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Calories Burned vs. Sleep Efficiency')

# %%
plt.figure(figsize=(18, 6))  

plt.subplot(1, 3, 1)
plt.scatter(cycles_df['Energy burned (cal)'], cycles_df['Light sleep duration (min)'], c='skyblue', marker='o', label='Data Points', edgecolor='black')
plt.xlabel('Calories Burned')
plt.ylabel('Light Sleep (Min)')
plt.title('Scatter Plot of Calories Burned vs. Light Sleep')

plt.subplot(1, 3, 2)
plt.scatter(cycles_df['Energy burned (cal)'], cycles_df['Deep (SWS) duration (min)'], c='skyblue', marker='o', label='Data Points', edgecolor='black')
plt.xlabel('Calories Burned')
plt.ylabel('Deep Sleep')
plt.title('Scatter Plot of Calories Burned vs. Deep Sleep)')

plt.subplot(1, 3, 3)
plt.scatter(cycles_df['Energy burned (cal)'], cycles_df['REM duration (min)'], c='skyblue', marker='o', label='Data Points', edgecolor='black')
plt.xlabel('Caloires Burned')
plt.ylabel('REM Sleep (Min)')
plt.title('Scatter Plot of Calories Burned vs. REM Sleep')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Calories Burned vs. REM Sleep')

# %%
correlation_matrix = cycles_df[['Energy burned (cal)', 'Asleep duration (min)', 'Sleep efficiency %','Light sleep duration (min)', 'Deep (SWS) duration (min)', 'REM duration (min)']].corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()

# %% [markdown]
# No correlation between Strain and Sleep and Calories Burned and Sleep

# %%
plt.figure(figsize=(8, 6))
plt.scatter(cycles_df['Recovery category'], cycles_df['Energy burned (cal)'], color='skyblue', edgecolor='black')
plt.title('Recovery category vs. Calories Burned')
plt.xlabel('Recovery Scores')
plt.ylabel('Calories Burned')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Even on my lowest days I am still burning over 3500 calories when it is reccomended I should be taking it easy.

# %% [markdown]
# ### Distrubtion throughout the Week

# %%
plt.figure(figsize=(8, 6))
plt.scatter(cycles_df['day_of_week'], cycles_df['Day Strain'], color='skyblue', edgecolor='black')
plt.title('Distribution of Recovery Scores')
plt.xlabel('Recovery Scores')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
cycles_df.corr()
# Out:
# /var/folders/23/9yyjjc7d5qzgg1rk2yt_yhwc0000gn/T/ipykernel_48247/1066167794.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cycles_df.corr()
#                              Recovery score %  Resting heart rate (bpm)  \
# Recovery score %                     1.000000                 -0.000556
# Resting heart rate (bpm)            -0.000556                  1.000000
# Heart rate variability (ms)          0.827196                  0.073014
# Day Strain                          -0.085441                 -0.133147
# Energy burned (cal)                 -0.036748                 -0.098473
# Max HR (bpm)                         0.092356                 -0.226118
# Average HR (bpm)                    -0.003583                 -0.053309
# Sleep performance %                  0.223696                  0.120412
# ...

# %%
strain = cycles_df['Day Strain']
sleep_efficiency = cycles_df['Sleep efficiency %']
sleep_duration = cycles_df['Asleep duration (min)']
calories_burned = cycles_df['Energy burned (cal)']
days_of_week = cycles_df['day_of_week']
